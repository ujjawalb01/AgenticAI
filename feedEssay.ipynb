# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict, Annotated
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import operator
import os

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class Evaluationschema(BaseModel):
    feedback:str  = Field(description='Detailed fedback for the essay')
    score: int  = Field(description='Score ot of 10', ge=0, le=10)

# %%
structured_model = llm.with_structured_output(Evaluationschema)

# %%
essay = """
Artificial Intelligence, commonly known as AI, is no longer just a concept seen in science-fiction movies or discussed only by scientists and technology experts. It has gradually become a part of everyday life, and India is emerging as one of the countries where AI is developing at a remarkable pace. From smartphones and online shopping to healthcare, education, agriculture, banking, transportation, and government services, artificial intelligence is slowly changing the way people live and work. What makes India’s AI journey particularly interesting is the combination of its large population, growing digital infrastructure, huge technology workforce, and increasing number of startups. India has already established itself as an important technology hub, and AI has the potential to take this position even further.

The evolution of AI in India has been gradual. In the early stages, artificial intelligence was mainly associated with academic research and large technology companies. There were limited resources, expensive computing systems, and fewer opportunities for ordinary people to experience AI directly. However, the situation began to change rapidly with the growth of the internet, smartphones, cloud computing, and digital services. The expansion of platforms such as digital payments, online education, e-commerce, and social media created enormous amounts of data that could be processed using modern AI techniques. At the same time, improvements in computing power and machine learning made it possible to build intelligent systems that could understand patterns, make predictions, and assist people in solving real-world problems.

One of the biggest reasons behind the growth of AI in India is the country's strong technology ecosystem. India has millions of engineers, developers, researchers, and IT professionals working in different areas of technology. Major technology companies have established research and development centers in India, while Indian startups are also building AI-based products for both Indian and international markets. Bengaluru, Hyderabad, Delhi-NCR, Mumbai, Pune, Chennai, and several other cities have become important centers for technology and innovation. Young entrepreneurs are using AI to solve problems in areas such as healthcare, finance, agriculture, customer service, cybersecurity, education, and logistics. This growing ecosystem is helping India move from being primarily a technology-services provider toward becoming a country that develops its own intelligent technologies and products.

AI is also becoming increasingly important in Indian healthcare. Hospitals and healthcare organizations are experimenting with AI systems that can assist doctors in analyzing medical images, identifying possible diseases, and managing patient information. In rural and remote areas, AI-powered tools may help improve access to medical knowledge and basic healthcare services. AI cannot replace doctors, but it can support them by processing large amounts of information quickly and identifying patterns that might otherwise take more time to detect. This is especially valuable in a country like India, where the demand for healthcare services is enormous and medical resources are not equally available everywhere.

Agriculture is another area where AI can have a significant impact. A large part of India's population is connected to agriculture, and farmers face challenges such as unpredictable weather, changing market prices, pests, water shortages, and crop diseases. AI can help analyze weather patterns, satellite images, soil information, and crop data to provide useful recommendations. Farmers can potentially use intelligent systems to understand when to plant crops, how much water to use, or whether a crop may be affected by a particular disease. If these technologies become affordable and accessible to small farmers, AI could contribute significantly to improving agricultural productivity and reducing unnecessary losses.

Education is also being transformed by artificial intelligence. Online learning platforms can use AI to understand how students learn and recommend content according to their individual needs. AI-powered assistants can answer questions, explain difficult concepts, generate practice questions, and provide immediate feedback. For students in India who may not have access to expensive coaching or personal tutors, such technologies can create new learning opportunities. However, education should not become completely dependent on AI. Teachers continue to play an essential role because learning is not only about receiving information; it also involves motivation, communication, creativity, discipline, and human understanding.

The financial sector in India has also benefited greatly from AI. Banks and financial institutions use machine learning for fraud detection, risk assessment, customer support, and analyzing financial behavior. AI can identify unusual transactions much faster than traditional systems and can help organizations respond to possible fraud. Chatbots and virtual assistants have also become common in banking and customer service. India's rapid adoption of digital payments has created an environment where AI can be used to make financial systems faster, safer, and more personalized.

Another important development is the growth of AI in Indian languages. India is one of the most linguistically diverse countries in the world, with hundreds of languages and dialects. For many years, digital technology was easier to access for people comfortable with English. Modern AI systems are increasingly capable of understanding and generating Indian languages, including Hindi and several regional languages. This could make technology more inclusive by allowing people to interact with computers and digital services in languages they naturally speak. Voice-based AI may be particularly useful for people who are less comfortable reading or typing in English.

At the same time, the rapid development of AI brings serious challenges. One of the biggest concerns is employment. AI can automate repetitive tasks, and some jobs may change or disappear as organizations adopt intelligent systems. However, history shows that technological progress can also create new types of jobs. The important issue is whether people receive the education and training needed to adapt. India therefore needs to focus heavily on digital literacy, AI education, programming, critical thinking, and reskilling. Instead of simply fearing that AI will take away jobs, society needs to prepare people to work alongside AI and use it as a tool to increase their productivity.

There are also concerns related to privacy, misinformation, bias, and responsible use of AI. AI systems learn from data, and if the data contains mistakes or biases, the system can sometimes produce unfair or inaccurate results. Generative AI has also made it easier to create realistic images, videos, audio, and written content, which can be misused to spread misinformation. India will therefore need strong policies and responsible practices to ensure that AI develops in a way that protects individuals while still encouraging innovation. Technology should be powerful, but it should also be trustworthy and accountable.

The future of AI in India looks extremely promising. With a large young population, a strong IT sector, growing startup culture, expanding digital infrastructure, and increasing interest in research and innovation, India has the potential to become one of the world's major AI economies. The real success of AI, however, should not be measured only by the number of AI companies or advanced technologies created. It should also be measured by how effectively AI improves people's lives. If AI can help a farmer make better decisions, help a student understand a difficult subject, help a doctor support a patient, help a small business reach customers, or make public services easier to access, then its development has genuine social value.

In conclusion, the evolution of Artificial Intelligence in India represents much more than a technological revolution. It is becoming a social and economic transformation that can influence almost every part of the country. India has the opportunity to become not just a consumer of AI technology but also a major creator of it. The journey will come with challenges, including employment concerns, privacy issues, unequal access, and ethical questions, but these challenges can be addressed through education, responsible innovation, effective policies, and human-centered development. AI should not be viewed as a replacement for human intelligence but as a powerful tool that can enhance human abilities. If India manages to combine its technological talent with responsible and inclusive development, artificial intelligence could play a major role in shaping a smarter, more productive, and more connected India in the coming years.

"""

# %%
promt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
structured_model.invoke(promt)
# Out:
# Evaluationschema(feedback="The essay provides a comprehensive overview of the development and impact of Artificial Intelligence in India, covering various sectors such as healthcare, agriculture, education, and finance. The language quality is excellent, with clear and concise sentences, proper grammar, and effective use of transitions to connect ideas. The author's arguments are well-supported with relevant examples and data, making the essay engaging and informative. However, there are some areas where the essay could be improved, such as providing more concrete statistics and data to support the claims, and addressing potential counterarguments to strengthen the author's position. Overall, the essay demonstrates a high level of writing proficiency and critical thinking skills.", score=9)

# %%
class UPSCState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int],operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState):
    
    promt = f"Evaluate the language quality of the following essay and provide feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(promt)
    
    return {'language_feedback': output.feedback,'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: UPSCState):
    
    promt = f"Evaluate the depth of analysis of the following essay and provide feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(promt)
    
    return {'analysis_feedback': output.feedback,'individual_scores': [output.score]}

# %%
def evaluate_thought(state: UPSCState):
    
    promt = f"Evaluate the clarity of thought of the following essay and provide feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(promt)
    
    return {'clarity_feedback': output.feedback,'individual_scores': [output.score]}

# %%
def fianl_evolution(state: UPSCState):
    
    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    
    overall_feedback = llm.invoke(prompt).content
    
    # average calculation
    
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])
    
    return {'overall_feedback': overall_feedback,'avg_score':avg_score}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('fianl_evolution',fianl_evolution)




# creating the edges

graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')


graph.add_edge(['evaluate_language', 'evaluate_analysis', 'evaluate_thought'], 'fianl_evolution')

graph.add_edge('fianl_evolution',END)

workflow = graph.compile()

# %%
initial_state = {
    'essay':essay
}

workflow.invoke(initial_state)
# Out:
# {'essay': "\nArtificial Intelligence, commonly known as AI, is no longer just a concept seen in science-fiction movies or discussed only by scientists and technology experts. It has gradually become a part of everyday life, and India is emerging as one of the countries where AI is developing at a remarkable pace. From smartphones and online shopping to healthcare, education, agriculture, banking, transportation, and government services, artificial intelligence is slowly changing the way people live and work. What makes India’s AI journey particularly interesting is the combination of its large population, growing digital infrastructure, huge technology workforce, and increasing number of startups. India has already established itself as an important technology hub, and AI has the potential to take this position even further.\n\nThe evolution of AI in India has been gradual. In the early stages, artificial intelligence was mainly associated with academic research and large technology 
# ...
