# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
import os

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
#  'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. In one sense, "crusty" can refer to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also be used to describe someone\'s mood or personality, implying that they are irritable, grumpy, or unpleasant.\n\nThe joke relies on this dual meaning to create a humorous connection between the setup ("Why was the pizza in a bad mood?") and the punchline ("Because it was feeling a little crusty!"). The unexpected twist on the word\'s meaning creates a clever and amusing play on words, making the joke entertaining and lighthearted.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. In one sense, "crusty" can refer to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also be used to describe someone\'s mood or personality, implying that they are irritable, grumpy, or unpleasant.\n\nThe joke relies on this dual meaning to create a humorous connection between the setup ("Why was the pizza in a bad mood?") and the punchline ("Because it was feeling a little crusty!"). The unexpected twist on the word\'s meaning creates a clever and amusing play on words, making the joke entertaining and lighthearted.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-62cc-6cce-8002-7b35d57ac8c8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-16T05:58:37.852986+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5cb5-6ba4-8001-43dd024ed5f8'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. In one sense, "crusty" can refer to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also be used to describe someone\'s mood or personality, implying that they are irritable, grumpy, or unpleasant.\n\nThe joke relies on this dual meaning to create a humorous connection between the setup ("Why was the pizza in a bad mood?") and the punchline ("Because it was feeling a little crusty!"). The unexpected twist on the word\'s meaning creates a clever and amusing play on words, making the joke entertaining and lighthearted.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-62cc-6cce-8002-7b35d57ac8c8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-16T05:58:37.852986+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5cb5-6ba4-8001-43dd024ed5f8'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5cb5-6ba4-8001-43dd024ed5f8'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-16T05:58:37.214389+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5974-6982-8000-ac55db603d50'}}, tasks=(PregelTask(id='701ad168-141d-715a-4e02-45efdd1f03a4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. In one sense, "crusty" can refer to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also be used to describe someone\'s mood or personality, implying that they are irritable, grumpy, or unpleasant.\n\nThe joke relies on this dual meaning to create a humorous connection between the setup ("Why was the pizza in a bad mood?") and the punchline ("Because it was feeling a little crusty!"). The unexpected twist on the word\'s meaning creates a clever and amusing play on words, making the joke entertaining and lighthearted.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5974-6982-8000-ac55db603d50'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-16T05:58:36.873143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5972-6bbc-bfff-6a80578b652a'}}, tasks=(PregelTask(id='117ed392-0fbe-7b5b-2276-2a9c4eefd687', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f199378-5972-6bbc-bfff-6a80578b652a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-16T05:58:36.872378+00:00', parent_config=None, tasks=(PregelTask(id='1be89593-f3a9-657d-f9c2-e92ce4bc972c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({"topic":"chowmine"},config=config2)
# Out:
# {'topic': 'chowmine',
#  'joke': 'Why did the chowmein go to therapy?\n\nBecause it was feeling a little "stir-crazy" and wanted to get to the root of its noodle problems!',
#  'explanation': 'A delightful play on words. This joke is a clever example of a pun, which relies on multiple meanings of words to create humor. Let\'s break it down:\n\nThe joke starts by setting up a unexpected scenario: a chowmein (a type of noodle dish) going to therapy. This already creates a sense of curiosity and absurdity.\n\nThe punchline "it was feeling a little \'stir-crazy\'" is where the wordplay begins. "Stir-crazy" is a common idiomatic expression that means feeling restless, anxious, or cooped up, often due to being confined to a small space for too long. However, in this context, "stir" also references the act of stirring, which is a common cooking technique used to prepare chowmein.\n\nThe second part of the punchline, "wanted to get to the root of its noodle problems," is another layer of wordplay. "Get to the root of" is a common phrase used to describe exploring the underlying causes of a problem. However, in this case, "noodle" has a double meaning: it refers to both the type of food (chowmein) and the idea of a problem or issue (as in, "a knotty problem" or "a noodle to untangle"). The phrase "noodle problems" is a clever play on words, using the food term to describe the chowmein\'s emotional or psychological issues.\n\nOverall, the joke relies on a quick mental shift between the different meanings of words, creating a sense of surprise and delight. The use of wordplay and clever language creates a lighthearted and humorous effect, making the joke enjoyable and engaging.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'chowmine', 'joke': 'Why did the chowmein go to therapy?\n\nBecause it was feeling a little "stir-crazy" and wanted to get to the root of its noodle problems!', 'explanation': 'A delightful play on words. This joke is a clever example of a pun, which relies on multiple meanings of words to create humor. Let\'s break it down:\n\nThe joke starts by setting up a unexpected scenario: a chowmein (a type of noodle dish) going to therapy. This already creates a sense of curiosity and absurdity.\n\nThe punchline "it was feeling a little \'stir-crazy\'" is where the wordplay begins. "Stir-crazy" is a common idiomatic expression that means feeling restless, anxious, or cooped up, often due to being confined to a small space for too long. However, in this context, "stir" also references the act of stirring, which is a common cooking technique used to prepare chowmein.\n\nThe second part of the punchline, "wanted to get to the root of its noodle problems," is another layer of wordplay. "Get to the root of" is a common phrase used to describe exploring the underlying causes of a problem. However, in this case, "noodle" has a double meaning: it refers to both the type of food (chowmein) and the idea of a problem or issue (as in, "a knotty problem" or "a noodle to untangle"). The phrase "noodle problems" is a clever play on words, using the food term to describe the chowmein\'s emotional or psychological issues.\n\nOverall, the joke relies on a quick mental shift between the different meanings of words, creating a sense of surprise and delight. The use of wordplay and clever language creates a lighthearted and humorous effect, making the joke enjoyable and engaging.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-6ae7-672b-8002-c9c18b896088'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-16T06:10:43.478484+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-6004-6000-8001-fb4f50dfbc31'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'chowmine', 'joke': 'Why did the chowmein go to therapy?\n\nBecause it was feeling a little "stir-crazy" and wanted to get to the root of its noodle problems!', 'explanation': 'A delightful play on words. This joke is a clever example of a pun, which relies on multiple meanings of words to create humor. Let\'s break it down:\n\nThe joke starts by setting up a unexpected scenario: a chowmein (a type of noodle dish) going to therapy. This already creates a sense of curiosity and absurdity.\n\nThe punchline "it was feeling a little \'stir-crazy\'" is where the wordplay begins. "Stir-crazy" is a common idiomatic expression that means feeling restless, anxious, or cooped up, often due to being confined to a small space for too long. However, in this context, "stir" also references the act of stirring, which is a common cooking technique used to prepare chowmein.\n\nThe second part of the punchline, "wanted to get to the root of its noodle problems," is another layer of wordplay. "Get to the root of" is a common phrase used to describe exploring the underlying causes of a problem. However, in this case, "noodle" has a double meaning: it refers to both the type of food (chowmein) and the idea of a problem or issue (as in, "a knotty problem" or "a noodle to untangle"). The phrase "noodle problems" is a clever play on words, using the food term to describe the chowmein\'s emotional or psychological issues.\n\nOverall, the joke relies on a quick mental shift between the different meanings of words, creating a sense of surprise and delight. The use of wordplay and clever language creates a lighthearted and humorous effect, making the joke enjoyable and engaging.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-6ae7-672b-8002-c9c18b896088'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-16T06:10:43.478484+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-6004-6000-8001-fb4f50dfbc31'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'chowmine', 'joke': 'Why did the chowmein go to therapy?\n\nBecause it was feeling a little "stir-crazy" and wanted to get to the root of its noodle problems!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-6004-6000-8001-fb4f50dfbc31'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-16T06:10:42.336753+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-5bb3-6919-8000-a2561ccc9cf0'}}, tasks=(PregelTask(id='3a5859e8-a60d-06a9-b717-556a421915ee', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A delightful play on words. This joke is a clever example of a pun, which relies on multiple meanings of words to create humor. Let\'s break it down:\n\nThe joke starts by setting up a unexpected scenario: a chowmein (a type of noodle dish) going to therapy. This already creates a sense of curiosity and absurdity.\n\nThe punchline "it was feeling a little \'stir-crazy\'" is where the wordplay begins. "Stir-crazy" is a common idiomatic expression that means feeling restless, anxious, or cooped up, often due to being confined to a small space for too long. However, in this context, "stir" also references the act of stirring, which is a common cooking technique used to prepare chowmein.\n\nThe second part of the punchline, "wanted to get to the root of its noodle problems," is another layer of wordplay. "Get to the root of" is a common phrase used to describe exploring the underlying causes of a problem. However, in this case, "noodle" has a double meaning: it refers to both the type of food (chowmein) and the idea of a problem or issue (as in, "a knotty problem" or "a noodle to untangle"). The phrase "noodle problems" is a clever play on words, using the food term to describe the chowmein\'s emotional or psychological issues.\n\nOverall, the joke relies on a quick mental shift between the different meanings of words, creating a sense of surprise and delight. The use of wordplay and clever language creates a lighthearted and humorous effect, making the joke enjoyable and engaging.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'chowmine'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-5bb3-6919-8000-a2561ccc9cf0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-16T06:10:41.884383+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-5bb1-6b75-bfff-98b12bdcab42'}}, tasks=(PregelTask(id='addfd8db-95e5-bf02-4876-8dd2029111d9', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the chowmein go to therapy?\n\nBecause it was feeling a little "stir-crazy" and wanted to get to the root of its noodle problems!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f199393-5bb1-6b75-bfff-98b12bdcab42'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-16T06:10:41.883625+00:00', parent_config=None, tasks=(PregelTask(id='68c786ba-af55-0040-ab3c-c34de7edaaa0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'chowmine'}),), interrupts=())]
